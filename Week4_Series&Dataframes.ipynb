# %% [markdown]
# <a href="https://colab.research.google.com/github/zoribecca/Data_Science_Practice_Projects/blob/main/Week4_Series%26Dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
seyi_dictionary = {"name":"seyi", "school":"3mtt", "track":"Data Science"}

# %%
data = pd.Series(seyi_dictionary)
data
# Out:
# name              seyi
# school            3mtt
# track     Data Science
# dtype: object

# %%
data_science_cohort2 = [{"name":"Kemi", "age": 25},
                        {"name":"Tola", "age": 21},
                        {"name":"Toheebat", "age": 22},
                        {"name":"Kola", "age": 27},
                        {"name":"Emmanuel", "age": 30},
                        {"name": "Joy", "age": 24}
                        ]

# %%
data = pd.DataFrame(data_science_cohort2)
data
# Out:
#        name  age
# 0      Kemi   25
# 1      Tola   21
# 2  Toheebat   22
# 3      Kola   27
# 4  Emmanuel   30
# 5       Joy   24

# %%
attendance = {"Class1":["Joy", "Rashidat", "Seyi"],
              "Class2":["Kemi", "Kelvin", "Titi"],
              "Class3":["Emmanuel", "Victor", "Kola"]
              }

# %%
data = pd.DataFrame(attendance)
data
# Out:
#      Class1  Class2    Class3
# 0       Joy    Kemi  Emmanuel
# 1  Rashidat  Kelvin    Victor
# 2      Seyi    Titi      Kola

# %%
bio_data = {"Fe00234": {"Name": "Seyi", "age": 23},
            "Fe00235": {"Name": "Ola", "age": 25},
            "Fe00236": {"Name": "Tobi", "age": 24}
            }

# %%
data = pd.DataFrame(bio_data)
data
# Out:
#      Fe00234 Fe00235 Fe00236
# Name    Seyi     Ola    Tobi
# age       23      25      24

# %%
data.columns
# Out:
# Index(['Fe00234', 'Fe00235', 'Fe00236'], dtype='object')

# %%
data.values
# Out:
# array([['Seyi', 'Ola', 'Tobi'],
#        [23, 25, 24]], dtype=object)

# %%
# pd.read_csv()
trip = pd.read_csv("/content/drive/MyDrive/3MTT WORKS/Datasets/trip (1).csv")

# %%
trip.head()
# Out:
#    trip_id         starttime          stoptime    bikeid  tripduration  \
# 0      431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1      432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2      433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3      434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4      435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
#
#      from_station_name                                    to_station_name  \
# 0  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 1  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 2  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 3  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 4  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
#
#   from_station_id to_station_id usertype  gender  birthyear
# ...
