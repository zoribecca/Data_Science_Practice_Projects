# %% [markdown]
# <a href="https://colab.research.google.com/github/zoribecca/Data_Science_Practice_Projects/blob/main/Week5_Trip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# pd.read_csv()
trip = pd.read_csv("/content/drive/MyDrive/3MTT WORKS/Datasets/trip (1).csv")

# %%
# To return the first 5 rows of the dataset
trip.head()
# Out:
#    trip_id         starttime          stoptime    bikeid  tripduration  \
# 0      431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1      432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2      433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3      434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4      435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
#
#      from_station_name                                    to_station_name  \
# 0  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 1  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 2  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 3  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 4  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
#
#   from_station_id to_station_id usertype  gender  birthyear
# ...

# %%
# To return the last 5 rows
trip.tail()
# Out:
#         trip_id        starttime         stoptime    bikeid  tripduration  \
# 236060   255241  8/31/2016 23:34  8/31/2016 23:45  SEA00201       679.532
# 236061   255242  8/31/2016 23:48    9/1/2016 0:20  SEA00247      1965.418
# 236062   255243  8/31/2016 23:47    9/1/2016 0:20  SEA00300      1951.173
# 236063   255244  8/31/2016 23:49    9/1/2016 0:20  SEA00047      1883.299
# 236064   255245  8/31/2016 23:49    9/1/2016 0:20  SEA00442      1896.031
#
#                              from_station_name        to_station_name  \
# 236060                 Harvard Ave & E Pine St    2nd Ave & Spring St
# 236061  Cal Anderson Park / 11th Ave & Pine St  6th Ave S & S King St
# 236062  Cal Anderson Park / 11th Ave & Pine St  6th Ave S & S King St
# 236063  Cal Anderson Park / 11th Ave & Pine St  6th Ave S & S King St
# 236064  Cal Anderson Park / 11th Ave & Pine St  6th Ave S & S King St
#
#        from_station_id to_station_id                usertype gender  birthyear
# ...

# %%
# To return the summary statistics of the dataset
trip.describe()
# Out:
#              trip_id  tripduration      birthyear
# count  236065.000000  236065.00000  146167.000000
# mean   130059.869333    1202.61221    1979.879740
# std     72842.289278    2066.42488      10.154978
# min       431.000000      60.00800    1931.000000
# 25%     67746.000000     392.26500    1975.000000
# 50%    130526.000000     633.23500    1983.000000
# 75%    192900.000000    1145.01500    1987.000000
# max    255245.000000   28794.39800    1999.000000

# %%
# To provide info about the dataset
trip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236065 entries, 0 to 236064
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   trip_id            236065 non-null  int64
#  1   starttime          236065 non-null  object
#  2   stoptime           236065 non-null  object
#  3   bikeid             236065 non-null  object
#  4   tripduration       236065 non-null  float64
#  5   from_station_name  236065 non-null  object
#  6   to_station_name    236065 non-null  object
#  7   from_station_id    236065 non-null  object
#  8   to_station_id      236065 non-null  object
#  9   usertype           236065 non-null  object
#  10  gender             146171 non-null  object
#  11  birthyear          146167 non-null  float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 21.6+ MB

# %%
# To return the dimension of the dataset
trip.shape
# Out:
# (236065, 12)

# %%
trip.loc[(trip["gender"] == "Female")].head(20)
# Out:
#     trip_id         starttime          stoptime    bikeid  tripduration  \
# 2       433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3       434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 8       439  10/13/2014 11:35  10/13/2014 11:45  SEA00486       586.347
# 10      441  10/13/2014 11:36  10/13/2014 11:45  SEA00195       564.899
# 15      446  10/13/2014 11:37  10/13/2014 11:47  SEA00106       618.781
# 18      450  10/13/2014 11:40  10/13/2014 11:49  SEA00107       499.734
# 23      456  10/13/2014 11:43  10/13/2014 11:51  SEA00121       483.154
# 24      457  10/13/2014 11:43  10/13/2014 11:51  SEA00029       479.382
# 25      458  10/13/2014 11:43  10/13/2014 11:52  SEA00436       533.532
# 28      461  10/13/2014 11:43  10/13/2014 11:51  SEA00348       459.165
# 30      463  10/13/2014 11:44  10/13/2014 12:00  SEA00296       920.055
# 34      467  10/13/2014 11:45  10/13/2014 12:00  SEA00155       860.538
# ...

# %%
trip.iloc[0:4,2:5]
# Out:
#            stoptime    bikeid  tripduration
# 0  10/13/2014 10:48  SEA00298       985.935
# 1  10/13/2014 10:48  SEA00195       926.375
# 2  10/13/2014 10:48  SEA00486       883.831
# 3  10/13/2014 10:48  SEA00333       865.937

# %%
trip["gender"].fillna("Male", inplace = True)   # inplace to indicate a permanent change
# Out:
# <ipython-input-10-31b5d32d2ea3>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   trip["gender"].fillna("Male", inplace = True)   # inplace to indicate a permanent change

# %%
trip.isna().sum()
# Out:
# trip_id                  0
# starttime                0
# stoptime                 0
# bikeid                   0
# tripduration             0
# from_station_name        0
# to_station_name          0
# from_station_id          0
# to_station_id            0
# usertype                 0
# gender                   0
# birthyear            89898
# dtype: int64

# %%
# Aggregators
# sum()
# mean()
# max()
# min()
# count()
# nunique()
# unique()
# value_counts()

# %%
# Using Groupby()
trip.groupby("gender").value_counts().tail(100)
# Out:
# gender  trip_id  starttime        stoptime         bikeid    tripduration  from_station_name               to_station_name                  from_station_id  to_station_id  usertype  birthyear
# Other   246479   8/11/2016 18:07  8/11/2016 18:11  SEA00124  243.106       15th Ave E & E Thomas St        E Pine St & 16th Ave             CH-05            CH-07          Member    1966.0       1
#         246495   8/11/2016 18:36  8/11/2016 18:45  SEA00111  572.324       1st Ave & Marion St             Pier 69 / Alaskan Way & Clay St  CBD-05           WF-01          Member    1957.0       1
#         246571   8/11/2016 20:34  8/11/2016 20:46  SEA00098  718.624       E Harrison St & Broadway Ave E  Broadway and E Denny Way         CH-02            CH-16          Member    1987.0       1
#         246638   8/12/2016 8:13   8/12/2016 8:19   SEA00282  307.387       15th Ave E & E Thomas St        Summit Ave & E Denny Way         CH-05            CH-01          Member    1966.0       1
# ...

# %%
gender_group = trip.groupby(["gender", "birthyear"])["trip_id"]

# %%
gender_group.count()
# Out:
# gender  birthyear
# Female  1931.0         1
#         1946.0        43
#         1947.0       691
#         1948.0         6
#         1949.0       132
#                     ...
# Other   1988.0         5
#         1989.0         1
#         1990.0        12
#         1992.0       153
#         1999.0         2
# Name: trip_id, Length: 135, dtype: int64

# %%
type("birthyear")
# Out:
# str

# %%
trip.astype({"birthyear" : "str"}).dtypes
# Out:
# trip_id                int64
# starttime             object
# stoptime              object
# bikeid                object
# tripduration         float64
# from_station_name     object
# to_station_name       object
# from_station_id       object
# to_station_id         object
# usertype              object
# gender                object
# birthyear             object
# dtype: object
